# %% [markdown]
# # MOVIE GENRE CLASSIFICATION

# %%
#import libraries
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report

# %%
# Load your movie dataset
data = pd.read_csv('movie_dataset.csv')

# %%
#print dataset
data
# Out:
#      Unnamed: 0  Rank                          Movie Names  \
# 0             0     1  Ramayana: The Legend of Prince Rama
# 1             1     2           Rocketry: The Nambi Effect
# 2             2     3                              Nayakan
# 3             3     4                             Gol Maal
# 4             4     5                           Anbe Sivam
# ..          ...   ...                                  ...
# 245         245   246                           Kai Po Che
# 246         246   247                       Poove Unakkaga
# 247         247   248                                Raazi
# 248         248   249                          Dasvidaniya
# 249         249   250                                  Dia
#
#                                                  Links  Rating  Year  \
# 0    https://www.imdb.com//title/tt0259534/?ref_=fe...     9.2  1993
# 1    https://www.imdb.com//title/tt9263550/?ref_=fe...     8.7  2022
# ...

# %%
#First Five
data.head()
# Out:
#    Unnamed: 0  Rank                          Movie Names  \
# 0           0     1  Ramayana: The Legend of Prince Rama
# 1           1     2           Rocketry: The Nambi Effect
# 2           2     3                              Nayakan
# 3           3     4                             Gol Maal
# 4           4     5                           Anbe Sivam
#
#                                                Links  Rating  Year  \
# 0  https://www.imdb.com//title/tt0259534/?ref_=fe...     9.2  1993
# 1  https://www.imdb.com//title/tt9263550/?ref_=fe...     8.7  2022
# 2  https://www.imdb.com//title/tt0093603/?ref_=fe...     8.6  1987
# 3  https://www.imdb.com//title/tt0079221/?ref_=fe...     8.5  1979
# 4  https://www.imdb.com//title/tt0367495/?ref_=fe...     8.6  2003
#
#   Duration_of_movie                                  Genere  \
# 0                PG  Animation,Action,Adventure,Back to top
# 1            2h 37m             Biography,Drama,Back to top
# ...

# %%
# Split dataset into train and test sets
X_train, X_test, y_train, y_test = train_test_split(data['Description'], data['Genere'], test_size=0.2, random_state=42)

# %%
# Create TF-IDF vectorizer
tfidf_vectorizer = TfidfVectorizer(max_features=5000)

# %%
# Transform text data into TF-IDF features
X_train_tfidf = tfidf_vectorizer.fit_transform(X_train.astype('U'))
X_test_tfidf = tfidf_vectorizer.transform(X_test.astype('U'))

# %%
# Creating and train a Random Forest classifier
rf_classifier = RandomForestClassifier(n_estimators=100, random_state=42)
rf_classifier.fit(X_train_tfidf, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
# Make predictions on model
y_pred = rf_classifier.predict(X_test_tfidf)

# %%
# Evaluating the model
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
print(classification_report(y_test, y_pred, zero_division=1))
# Out:
# Accuracy: 0.06
#                                      precision    recall  f1-score   support
#
# Action,Adventure,Sci-Fi,Back to top       1.00      0.00      0.00         1
#  Action,Biography,Crime,Back to top       1.00      0.00      0.00         2
#  Action,Biography,Drama,Back to top       1.00      0.00      0.00         2
#      Action,Crime,Drama,Back to top       0.11      0.60      0.18         5
#   Action,Crime,Thriller,Back to top       1.00      0.00      0.00         3
#            Action,Drama,Back to top       0.00      0.00      1.00         3
#    Action,Drama,History,Back to top       1.00      0.00      0.00         1
#    Action,Drama,Mystery,Back to top       1.00      0.00      0.00         1
#      Action,Drama,Sport,Back to top       1.00      0.00      0.00         1
#   Action,Drama,Thriller,Back to top       0.00      0.00      1.00         2
# Adventure,Drama,Romance,Back to top       1.00      0.00      0.00         1
# ...
